# %%
import numpy as np
import pandas as pd

# load dataset
df = pd.read_csv(r"/content/finalencodedds.csv")

# keep only demographic one-hot columns
context_cols = [col for col in df.columns if col.startswith("marital_status_")
                or col.startswith("age_range_")
                or col.startswith("family_size_")
                or col.startswith("income_bracket_")]

X = df[context_cols].values
A = df["coupon_id"].values
R = df["reward"].values

# initialize LinUCB memory
d = X.shape[1]
alpha = 0.1
actions = np.unique(A)
A_matrices = {a: np.eye(d) for a in actions}
b_vectors = {a: np.zeros(d) for a in actions}

# training loop
for i in range(len(X)):
    x_t = X[i]
    a_t = A[i]
    r_t = R[i]
    A_matrices[a_t] += np.outer(x_t, x_t)
    b_vectors[a_t] += r_t * x_t

# compute theta for each coupon
theta = {a: np.linalg.inv(A_matrices[a]).dot(b_vectors[a]) for a in actions}

# turn one-hot rows into readable profile strings
def profile_from_row(row):
    active = [col for col in context_cols if row[col] == 1]
    return "|".join(active) if active else "Unknown"

df["profile"] = df[context_cols].apply(profile_from_row, axis=1)

# group by profile
grouped_profiles = df.groupby("profile")

recommendations = []
for profile, group in grouped_profiles:
    x_vector = group[context_cols].iloc[0].values  # representative vector
    scores = {a: theta[a].dot(x_vector) for a in actions}
    best_coupon = max(scores.items(), key=lambda x: x[1])
    recommendations.append((profile, best_coupon[0], best_coupon[1], len(group)))

for rec in recommendations:
    print(f"Profile: {rec[0]} | Group size: {rec[3]} → Best coupon {rec[1]} with predicted value {rec[2]:.2f}")
# Out:
# Profile: marital_status_Married|age_range_26-35|family_size_2|income_bracket_5.0 | Group size: 16 → Best coupon 19 with predicted value 3.00
# Profile: marital_status_Married|age_range_26-35|family_size_3|income_bracket_4.0 | Group size: 10 → Best coupon 872 with predicted value 1.49
# Profile: marital_status_Married|age_range_26-35|family_size_4|income_bracket_1.0 | Group size: 20 → Best coupon 526 with predicted value 2.24
# Profile: marital_status_Married|age_range_26-35|family_size_4|income_bracket_6.0 | Group size: 37 → Best coupon 97 with predicted value 2.98
# Profile: marital_status_Married|age_range_26-35|family_size_4|income_bracket_9.0 | Group size: 47 → Best coupon 526 with predicted value 2.98
# Profile: marital_status_Married|age_range_26-35|family_size_5+|income_bracket_4.0 | Group size: 15 → Best coupon 960 with predicted value 1.49
# Profile: marital_status_Married|age_range_36-45|family_size_2|income_bracket_3.0 | Group size: 3 → Best coupon 960 with predicted value 2.49
# Profile: marital_status_Married|age_range_36-45|family_size_2|income_bracket_4.0 | Group size: 69 → Best coupon 960 with predicted value 2.99
# Profile: marital_status_Married|age_range_36-45|family_size_2|income_bracket_5.0 | Group size: 114 → Best coupon 19 with predicted value 3.00
# Profile: marital_status_Married|age_range_36-45|family_size_2|income_bracket_8.0 | Group size: 9 → Best coupon 1044 with predicted value 2.92
# Profile: marital_status_Married|age_range_36-45|family_size_3|income_bracket_11.0 | Group size: 10 → Best coupon 872 with predicted value 2.24
# Profile: marital_status_Married|age_range_36-45|family_size_3|income_bracket_5.0 | Group size: 4 → Best coupon 948 with predicted value 2.82
# Profile: marital_status_Married|age_range_36-45|family_size_3|income_bracket_7.0 | Group size: 72 → Best coupon 872 with predicted value 2.99
# Profile: marital_status_Married|age_range_36-45|family_size_4|income_bracket_5.0 | Group size: 10 → Best coupon 109 with predicted value 2.92
# Profile: marital_status_Married|age_range_36-45|family_size_5+|income_bracket_2.0 | Group size: 10 → Best coupon 971 with predicted value 2.93
# Profile: marital_status_Married|age_range_36-45|family_size_5+|income_bracket_4.0 | Group size: 43 → Best coupon 960 with predicted value 2.24
# Profile: marital_status_Married|age_range_36-45|family_size_5+|income_bracket_8.0 | Group size: 5 → Best coupon 971 with predicted value 2.20
# Profile: marital_status_Married|age_range_46-55 | Group size: 1 → Best coupon 7 with predicted value nan
# Profile: marital_status_Married|age_range_46-55|family_size_2|income_bracket_12.0 | Group size: 2 → Best coupon 129 with predicted value 2.67
# Profile: marital_status_Married|age_range_46-55|family_size_2|income_bracket_2.0 | Group size: 24 → Best coupon 416 with predicted value 2.24
# Profile: marital_status_Married|age_range_46-55|family_size_2|income_bracket_3.0 | Group size: 119 → Best coupon 913 with predicted value 2.99
# Profile: marital_status_Married|age_range_46-55|family_size_2|income_bracket_5.0 | Group size: 112 → Best coupon 416 with predicted value 2.98
# Profile: marital_status_Married|age_range_46-55|family_size_2|income_bracket_6.0 | Group size: 18 → Best coupon 459 with predicted value 2.91
# Profile: marital_status_Married|age_range_46-55|family_size_2|income_bracket_7.0 | Group size: 67 → Best coupon 416 with predicted value 2.24
# Profile: marital_status_Married|age_range_46-55|family_size_3|income_bracket_5.0 | Group size: 259 → Best coupon 416 with predicted value 2.24
# Profile: marital_status_Married|age_range_56-70|family_size_2|income_bracket_1.0 | Group size: 40 → Best coupon 750 with predicted value 2.16
# Profile: marital_status_Married|age_range_56-70|family_size_2|income_bracket_3.0 | Group size: 83 → Best coupon 913 with predicted value 2.33
# Profile: marital_status_Married|age_range_56-70|family_size_2|income_bracket_4.0 | Group size: 6 → Best coupon 750 with predicted value 2.88
# Profile: marital_status_Married|age_range_56-70|family_size_2|income_bracket_5.0 | Group size: 2946 → Best coupon 19 with predicted value 2.50
# Profile: marital_status_Married|age_range_56-70|family_size_2|income_bracket_6.0 | Group size: 3718 → Best coupon 459 with predicted value 2.18
# Profile: marital_status_Married|age_range_56-70|family_size_4|income_bracket_6.0 | Group size: 134 → Best coupon 97 with predicted value 2.23
# Profile: marital_status_Married|age_range_56-70|family_size_5+|income_bracket_5.0 | Group size: 9 → Best coupon 19 with predicted value 1.50
# Profile: marital_status_Married|age_range_70+|family_size_2|income_bracket_5.0 | Group size: 15 → Best coupon 19 with predicted value 2.50
# Profile: marital_status_Married|age_range_70+|family_size_3|income_bracket_7.0 | Group size: 15 → Best coupon 616 with predicted value 2.95
# Profile: marital_status_Single|age_range_18-25|family_size_2|income_bracket_1.0 | Group size: 11 → Best coupon 663 with predicted value 2.93
# Profile: marital_status_Single|age_range_26-35|family_size_3|income_bracket_1.0 | Group size: 24 → Best coupon 663 with predicted value 1.47
# Profile: marital_status_Single|age_range_36-45|family_size_1|income_bracket_2.0 | Group size: 27 → Best coupon 278 with predicted value 2.97
# Profile: marital_status_Single|age_range_36-45|family_size_1|income_bracket_3.0 | Group size: 229 → Best coupon 278 with predicted value 2.23
# Profile: marital_status_Single|age_range_36-45|family_size_1|income_bracket_8.0 | Group size: 9 → Best coupon 278 with predicted value 2.23
# Profile: marital_status_Single|age_range_36-45|family_size_2|income_bracket_4.0 | Group size: 38 → Best coupon 520 with predicted value 2.24
# Profile: marital_status_Single|age_range_36-45|family_size_3|income_bracket_6.0 | Group size: 1 → Best coupon 60 with predicted value 1.60
# Profile: marital_status_Single|age_range_46-55|family_size_1|income_bracket_4.0 | Group size: 38 → Best coupon 554 with predicted value 2.19
# Profile: marital_status_Single|age_range_46-55|family_size_2|income_bracket_4.0 | Group size: 15 → Best coupon 520 with predicted value 2.24
# Profile: marital_status_Single|age_range_46-55|family_size_2|income_bracket_5.0 | Group size: 4 → Best coupon 490 with predicted value 2.82
# Profile: marital_status_Single|age_range_46-55|family_size_3|income_bracket_5.0 | Group size: 2 → Best coupon 490 with predicted value 2.12
# Profile: marital_status_Single|age_range_46-55|family_size_4|income_bracket_3.0 | Group size: 11 → Best coupon 437 with predicted value 2.93
# Profile: marital_status_Single|age_range_56-70|family_size_1|income_bracket_4.0 | Group size: 9 → Best coupon 554 with predicted value 2.92
# Profile: marital_status_Single|age_range_56-70|family_size_2|income_bracket_4.0 | Group size: 71 → Best coupon 520 with predicted value 2.99
# Profile: marital_status_Single|age_range_70+|family_size_1|income_bracket_2.0 | Group size: 32 → Best coupon 687 with predicted value 2.98
# Profile: marital_status_Single|age_range_70+|family_size_1|income_bracket_4.0 | Group size: 13 → Best coupon 687 with predicted value 2.23
# Profile: marital_status_Single|age_range_70+|family_size_2|income_bracket_4.0 | Group size: 3 → Best coupon 520 with predicted value 2.24
# Profile: marital_status_Unknown|age_range_18-25|family_size_1|income_bracket_1.0 | Group size: 8 → Best coupon 506 with predicted value 2.90
# Profile: marital_status_Unknown|age_range_18-25|family_size_4|income_bracket_4.0 | Group size: 31 → Best coupon 911 with predicted value 2.98
# Profile: marital_status_Unknown|age_range_26-35|family_size_1|income_bracket_4.0 | Group size: 87 → Best coupon 506 with predicted value 1.74
# Profile: marital_status_Unknown|age_range_26-35|family_size_2|income_bracket_4.0 | Group size: 214 → Best coupon 19 with predicted value 2.00
# Profile: marital_status_Unknown|age_range_26-35|family_size_2|income_bracket_5.0 | Group size: 114 → Best coupon 19 with predicted value 3.00
# Profile: marital_status_Unknown|age_range_26-35|family_size_4|income_bracket_6.0 | Group size: 14 → Best coupon 473 with predicted value 2.95
# Profile: marital_status_Unknown|age_range_26-35|family_size_5+|income_bracket_5.0 | Group size: 5 → Best coupon 19 with predicted value 2.00
# Profile: marital_status_Unknown|age_range_36-45|family_size_1|income_bracket_1.0 | Group size: 38 → Best coupon 890 with predicted value 2.98
# Profile: marital_status_Unknown|age_range_36-45|family_size_1|income_bracket_2.0 | Group size: 36 → Best coupon 1031 with predicted value 2.97
# Profile: marital_status_Unknown|age_range_36-45|family_size_1|income_bracket_5.0 | Group size: 22 → Best coupon 538 with predicted value 2.92
# Profile: marital_status_Unknown|age_range_36-45|family_size_2|income_bracket_1.0 | Group size: 21 → Best coupon 444 with predicted value 2.95
# Profile: marital_status_Unknown|age_range_36-45|family_size_2|income_bracket_3.0 | Group size: 16 → Best coupon 118 with predicted value 2.95
# Profile: marital_status_Unknown|age_range_46-55|family_size_1|income_bracket_2.0 | Group size: 12 → Best coupon 131 with predicted value 2.94
# Profile: marital_status_Unknown|age_range_46-55|family_size_1|income_bracket_3.0 | Group size: 77 → Best coupon 1028 with predicted value 2.88
# Profile: marital_status_Unknown|age_range_46-55|family_size_1|income_bracket_4.0 | Group size: 7 → Best coupon 989 with predicted value 2.22
# Profile: marital_status_Unknown|age_range_46-55|family_size_1|income_bracket_5.0 | Group size: 238 → Best coupon 467 with predicted value 2.99
# Profile: marital_status_Unknown|age_range_46-55|family_size_1|income_bracket_9.0 | Group size: 23 → Best coupon 989 with predicted value 2.96
# Profile: marital_status_Unknown|age_range_46-55|family_size_2|income_bracket_1.0 | Group size: 50 → Best coupon 902 with predicted value 2.99
# Profile: marital_status_Unknown|age_range_46-55|family_size_2|income_bracket_5.0 | Group size: 47 → Best coupon 800 with predicted value 2.97
# Profile: marital_status_Unknown|age_range_46-55|family_size_3|income_bracket_10.0 | Group size: 31 → Best coupon 14 with predicted value 1.95
# Profile: marital_status_Unknown|age_range_46-55|family_size_5+|income_bracket_8.0 | Group size: 30 → Best coupon 723 with predicted value 1.98
# Profile: marital_status_Unknown|age_range_56-70|family_size_3|income_bracket_3.0 | Group size: 15 → Best coupon 118 with predicted value 1.48
# Profile: marital_status_Unknown|age_range_70+|family_size_1|income_bracket_2.0 | Group size: 95 → Best coupon 687 with predicted value 2.48
# Profile: marital_status_Unknown|age_range_70+|family_size_2|income_bracket_3.0 | Group size: 2 → Best coupon 788 with predicted value 2.22
# Profile: marital_status_Unknown|age_range_70+|family_size_2|income_bracket_4.0 | Group size: 16 → Best coupon 788 with predicted value 2.22
# Profile: marital_status_Unknown|age_range_70+|family_size_2|income_bracket_5.0 | Group size: 22 → Best coupon 788 with predicted value 2.97
# Profile: marital_status_Unknown|age_range_70+|family_size_3|income_bracket_1.0 | Group size: 6 → Best coupon 506 with predicted value 1.74
# Profile: marital_status_Unknown|age_range_Unknown|family_size_Unknown|income_bracket_Unknown | Group size: 14451 → Best coupon 8 with predicted value 3.00
