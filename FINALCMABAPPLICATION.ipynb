# %%
import numpy as np
import pandas as pd

# load dataset
df = pd.read_csv("/content/finalencodeddsfr.csv")

# keep only demographic one-hot columns
context_cols = [col for col in df.columns if col.startswith("marital_status_")
                or col.startswith("age_range_")
                or col.startswith("family_size_")
                or col.startswith("income_bracket_")]

X = df[context_cols].values
A = df["coupon_id"].values
R = df["reward"].values

# initialize LinUCB memory
d = X.shape[1]
alpha = 0.1
actions = np.unique(A)
A_matrices = {a: np.eye(d) for a in actions}
b_vectors = {a: np.zeros(d) for a in actions}

# training loop
for i in range(len(X)):
    x_t = X[i]
    a_t = A[i]
    r_t = R[i]
    A_matrices[a_t] += np.outer(x_t, x_t)
    b_vectors[a_t] += r_t * x_t

# compute theta for each coupon
theta = {a: np.linalg.inv(A_matrices[a]).dot(b_vectors[a]) for a in actions}

# turn one-hot rows into readable profile strings
def profile_from_row(row):
    active = [col for col in context_cols if row[col] == 1]
    return "|".join(active) if active else "Unknown"

df["profile"] = df[context_cols].apply(profile_from_row, axis=1)

# group by profile
grouped_profiles = df.groupby("profile")

recommendations = []
for profile, group in grouped_profiles:
    x_vector = group[context_cols].iloc[0].values  # representative vector
    scores = {a: theta[a].dot(x_vector) for a in actions}
    best_coupon = max(scores.items(), key=lambda x: x[1])
    recommendations.append((profile, best_coupon[0], best_coupon[1], len(group)))

for rec in recommendations:
    print(f"Profile: {rec[0]} | Group size: {rec[3]} → Best coupon {rec[1]} with predicted value {rec[2]:.2f}")
# Out:
# Profile: marital_status_Married|age_range_18-25|family_size_2|income_bracket_11.0 | Group size: 2 → Best coupon 1075 with predicted value 2.09
# Profile: marital_status_Married|age_range_18-25|family_size_2|income_bracket_2.0 | Group size: 3 → Best coupon 529 with predicted value 2.22
# Profile: marital_status_Married|age_range_18-25|family_size_2|income_bracket_4.0 | Group size: 7 → Best coupon 1075 with predicted value 2.19
# Profile: marital_status_Married|age_range_18-25|family_size_3|income_bracket_2.0 | Group size: 2 → Best coupon 982 with predicted value 2.06
# Profile: marital_status_Married|age_range_18-25|family_size_3|income_bracket_4.0 | Group size: 4 → Best coupon 619 with predicted value 1.95
# Profile: marital_status_Married|age_range_18-25|family_size_3|income_bracket_5.0 | Group size: 47 → Best coupon 870 with predicted value 2.17
# Profile: marital_status_Married|age_range_18-25|family_size_3|income_bracket_6.0 | Group size: 2 → Best coupon 597 with predicted value 2.10
# Profile: marital_status_Married|age_range_26-35|family_size_2|income_bracket_1.0 | Group size: 41 → Best coupon 661 with predicted value 2.06
# Profile: marital_status_Married|age_range_26-35|family_size_2|income_bracket_3.0 | Group size: 3 → Best coupon 619 with predicted value 2.15
# Profile: marital_status_Married|age_range_26-35|family_size_2|income_bracket_4.0 | Group size: 23 → Best coupon 808 with predicted value 2.30
# Profile: marital_status_Married|age_range_26-35|family_size_2|income_bracket_5.0 | Group size: 141 → Best coupon 526 with predicted value 2.32
# Profile: marital_status_Married|age_range_26-35|family_size_2|income_bracket_6.0 | Group size: 170 → Best coupon 27 with predicted value 2.28
# Profile: marital_status_Married|age_range_26-35|family_size_2|income_bracket_8.0 | Group size: 5 → Best coupon 64 with predicted value 2.12
# Profile: marital_status_Married|age_range_26-35|family_size_3|income_bracket_2.0 | Group size: 12 → Best coupon 468 with predicted value 2.21
# Profile: marital_status_Married|age_range_26-35|family_size_3|income_bracket_3.0 | Group size: 55 → Best coupon 960 with predicted value 2.14
# Profile: marital_status_Married|age_range_26-35|family_size_3|income_bracket_4.0 | Group size: 82 → Best coupon 770 with predicted value 2.12
# Profile: marital_status_Married|age_range_26-35|family_size_3|income_bracket_5.0 | Group size: 36 → Best coupon 526 with predicted value 2.32
# Profile: marital_status_Married|age_range_26-35|family_size_3|income_bracket_6.0 | Group size: 45 → Best coupon 868 with predicted value 2.12
# Profile: marital_status_Married|age_range_26-35|family_size_3|income_bracket_7.0 | Group size: 185 → Best coupon 1081 with predicted value 2.21
# Profile: marital_status_Married|age_range_26-35|family_size_3|income_bracket_8.0 | Group size: 7 → Best coupon 868 with predicted value 2.11
# Profile: marital_status_Married|age_range_26-35|family_size_4|income_bracket_1.0 | Group size: 10 → Best coupon 661 with predicted value 1.95
# Profile: marital_status_Married|age_range_26-35|family_size_4|income_bracket_2.0 | Group size: 6 → Best coupon 705 with predicted value 1.92
# Profile: marital_status_Married|age_range_26-35|family_size_4|income_bracket_5.0 | Group size: 244 → Best coupon 526 with predicted value 2.12
# Profile: marital_status_Married|age_range_26-35|family_size_4|income_bracket_6.0 | Group size: 5 → Best coupon 601 with predicted value 1.97
# Profile: marital_status_Married|age_range_26-35|family_size_4|income_bracket_7.0 | Group size: 20 → Best coupon 1081 with predicted value 2.10
# Profile: marital_status_Married|age_range_26-35|family_size_4|income_bracket_9.0 | Group size: 21 → Best coupon 22 with predicted value 1.95
# Profile: marital_status_Married|age_range_26-35|family_size_5+|income_bracket_11.0 | Group size: 46 → Best coupon 624 with predicted value 1.76
# Profile: marital_status_Married|age_range_26-35|family_size_5+|income_bracket_4.0 | Group size: 91 → Best coupon 983 with predicted value 2.05
# Profile: marital_status_Married|age_range_26-35|family_size_5+|income_bracket_5.0 | Group size: 59 → Best coupon 678 with predicted value 2.25
# Profile: marital_status_Married|age_range_26-35|family_size_5+|income_bracket_7.0 | Group size: 44 → Best coupon 6 with predicted value 2.01
# Profile: marital_status_Married|age_range_26-35|family_size_5+|income_bracket_8.0 | Group size: 67 → Best coupon 754 with predicted value 1.96
# Profile: marital_status_Married|age_range_36-45|family_size_2|income_bracket_1.0 | Group size: 66 → Best coupon 91 with predicted value 2.24
# Profile: marital_status_Married|age_range_36-45|family_size_2|income_bracket_10.0 | Group size: 7 → Best coupon 532 with predicted value 2.36
# Profile: marital_status_Married|age_range_36-45|family_size_2|income_bracket_3.0 | Group size: 4 → Best coupon 597 with predicted value 2.27
# Profile: marital_status_Married|age_range_36-45|family_size_2|income_bracket_4.0 | Group size: 293 → Best coupon 759 with predicted value 2.34
# Profile: marital_status_Married|age_range_36-45|family_size_2|income_bracket_5.0 | Group size: 285 → Best coupon 885 with predicted value 2.43
# Profile: marital_status_Married|age_range_36-45|family_size_2|income_bracket_6.0 | Group size: 88 → Best coupon 27 with predicted value 2.52
# Profile: marital_status_Married|age_range_36-45|family_size_2|income_bracket_7.0 | Group size: 8 → Best coupon 759 with predicted value 2.30
# Profile: marital_status_Married|age_range_36-45|family_size_2|income_bracket_8.0 | Group size: 126 → Best coupon 759 with predicted value 2.21
# Profile: marital_status_Married|age_range_36-45|family_size_2|income_bracket_9.0 | Group size: 33 → Best coupon 492 with predicted value 2.32
# Profile: marital_status_Married|age_range_36-45|family_size_3|income_bracket_1.0 | Group size: 13 → Best coupon 960 with predicted value 2.15
# Profile: marital_status_Married|age_range_36-45|family_size_3|income_bracket_11.0 | Group size: 12 → Best coupon 276 with predicted value 1.92
# Profile: marital_status_Married|age_range_36-45|family_size_3|income_bracket_12.0 | Group size: 47 → Best coupon 619 with predicted value 1.94
# Profile: marital_status_Married|age_range_36-45|family_size_3|income_bracket_2.0 | Group size: 2 → Best coupon 960 with predicted value 2.21
# Profile: marital_status_Married|age_range_36-45|family_size_3|income_bracket_4.0 | Group size: 319 → Best coupon 510 with predicted value 2.12
# Profile: marital_status_Married|age_range_36-45|family_size_3|income_bracket_5.0 | Group size: 135 → Best coupon 870 with predicted value 2.12
# Profile: marital_status_Married|age_range_36-45|family_size_3|income_bracket_6.0 | Group size: 338 → Best coupon 597 with predicted value 2.19
# Profile: marital_status_Married|age_range_36-45|family_size_3|income_bracket_7.0 | Group size: 16 → Best coupon 597 with predicted value 2.03
# Profile: marital_status_Married|age_range_36-45|family_size_3|income_bracket_8.0 | Group size: 3 → Best coupon 597 with predicted value 2.26
# Profile: marital_status_Married|age_range_36-45|family_size_3|income_bracket_9.0 | Group size: 102 → Best coupon 960 with predicted value 2.17
# Profile: marital_status_Married|age_range_36-45|family_size_4|income_bracket_2.0 | Group size: 58 → Best coupon 674 with predicted value 1.97
# Profile: marital_status_Married|age_range_36-45|family_size_4|income_bracket_4.0 | Group size: 3 → Best coupon 559 with predicted value 2.18
# Profile: marital_status_Married|age_range_36-45|family_size_4|income_bracket_5.0 | Group size: 119 → Best coupon 316 with predicted value 2.12
# Profile: marital_status_Married|age_range_36-45|family_size_4|income_bracket_7.0 | Group size: 110 → Best coupon 759 with predicted value 2.06
# Profile: marital_status_Married|age_range_36-45|family_size_4|income_bracket_8.0 | Group size: 29 → Best coupon 597 with predicted value 2.23
# Profile: marital_status_Married|age_range_36-45|family_size_5+|income_bracket_12.0 | Group size: 20 → Best coupon 671 with predicted value 2.05
# Profile: marital_status_Married|age_range_36-45|family_size_5+|income_bracket_2.0 | Group size: 47 → Best coupon 468 with predicted value 2.26
# Profile: marital_status_Married|age_range_36-45|family_size_5+|income_bracket_3.0 | Group size: 8 → Best coupon 960 with predicted value 2.08
# Profile: marital_status_Married|age_range_36-45|family_size_5+|income_bracket_4.0 | Group size: 65 → Best coupon 510 with predicted value 2.06
# Profile: marital_status_Married|age_range_36-45|family_size_5+|income_bracket_5.0 | Group size: 360 → Best coupon 307 with predicted value 2.07
# Profile: marital_status_Married|age_range_36-45|family_size_5+|income_bracket_6.0 | Group size: 70 → Best coupon 27 with predicted value 2.07
# Profile: marital_status_Married|age_range_36-45|family_size_5+|income_bracket_7.0 | Group size: 9 → Best coupon 6 with predicted value 2.07
# Profile: marital_status_Married|age_range_36-45|family_size_5+|income_bracket_8.0 | Group size: 84 → Best coupon 754 with predicted value 1.99
# Profile: marital_status_Married|age_range_36-45|family_size_5+|income_bracket_9.0 | Group size: 57 → Best coupon 492 with predicted value 2.02
# Profile: marital_status_Married|age_range_46-55|family_size_2|income_bracket_1.0 | Group size: 52 → Best coupon 572 with predicted value 2.19
# Profile: marital_status_Married|age_range_46-55|family_size_2|income_bracket_10.0 | Group size: 100 → Best coupon 754 with predicted value 1.99
# Profile: marital_status_Married|age_range_46-55|family_size_2|income_bracket_11.0 | Group size: 12 → Best coupon 424 with predicted value 2.13
# Profile: marital_status_Married|age_range_46-55|family_size_2|income_bracket_12.0 | Group size: 194 → Best coupon 1075 with predicted value 2.05
# Profile: marital_status_Married|age_range_46-55|family_size_2|income_bracket_2.0 | Group size: 52 → Best coupon 468 with predicted value 2.18
# Profile: marital_status_Married|age_range_46-55|family_size_2|income_bracket_3.0 | Group size: 76 → Best coupon 865 with predicted value 2.36
# Profile: marital_status_Married|age_range_46-55|family_size_2|income_bracket_4.0 | Group size: 33 → Best coupon 808 with predicted value 2.33
# Profile: marital_status_Married|age_range_46-55|family_size_2|income_bracket_5.0 | Group size: 568 → Best coupon 885 with predicted value 2.46
# Profile: marital_status_Married|age_range_46-55|family_size_2|income_bracket_6.0 | Group size: 383 → Best coupon 812 with predicted value 2.18
# Profile: marital_status_Married|age_range_46-55|family_size_2|income_bracket_7.0 | Group size: 90 → Best coupon 113 with predicted value 2.29
# Profile: marital_status_Married|age_range_46-55|family_size_2|income_bracket_8.0 | Group size: 42 → Best coupon 1070 with predicted value 2.14
# Profile: marital_status_Married|age_range_46-55|family_size_2|income_bracket_9.0 | Group size: 56 → Best coupon 819 with predicted value 2.08
# Profile: marital_status_Married|age_range_46-55|family_size_3|income_bracket_1.0 | Group size: 22 → Best coupon 625 with predicted value 2.14
# Profile: marital_status_Married|age_range_46-55|family_size_3|income_bracket_3.0 | Group size: 11 → Best coupon 865 with predicted value 2.31
# Profile: marital_status_Married|age_range_46-55|family_size_3|income_bracket_4.0 | Group size: 11 → Best coupon 808 with predicted value 2.13
# Profile: marital_status_Married|age_range_46-55|family_size_3|income_bracket_5.0 | Group size: 131 → Best coupon 865 with predicted value 2.23
# Profile: marital_status_Married|age_range_46-55|family_size_3|income_bracket_6.0 | Group size: 72 → Best coupon 610 with predicted value 2.04
# Profile: marital_status_Married|age_range_46-55|family_size_3|income_bracket_7.0 | Group size: 4 → Best coupon 1081 with predicted value 2.03
# Profile: marital_status_Married|age_range_46-55|family_size_3|income_bracket_8.0 | Group size: 195 → Best coupon 1048 with predicted value 2.05
# Profile: marital_status_Married|age_range_46-55|family_size_4|income_bracket_2.0 | Group size: 11 → Best coupon 529 with predicted value 2.13
# Profile: marital_status_Married|age_range_46-55|family_size_4|income_bracket_4.0 | Group size: 18 → Best coupon 819 with predicted value 2.19
# Profile: marital_status_Married|age_range_46-55|family_size_4|income_bracket_5.0 | Group size: 51 → Best coupon 817 with predicted value 2.33
# Profile: marital_status_Married|age_range_46-55|family_size_4|income_bracket_6.0 | Group size: 33 → Best coupon 817 with predicted value 2.12
# Profile: marital_status_Married|age_range_46-55|family_size_5+|income_bracket_1.0 | Group size: 132 → Best coupon 91 with predicted value 2.11
# Profile: marital_status_Married|age_range_46-55|family_size_5+|income_bracket_3.0 | Group size: 137 → Best coupon 865 with predicted value 2.03
# Profile: marital_status_Married|age_range_46-55|family_size_5+|income_bracket_4.0 | Group size: 58 → Best coupon 1070 with predicted value 2.21
# Profile: marital_status_Married|age_range_46-55|family_size_5+|income_bracket_5.0 | Group size: 4 → Best coupon 1070 with predicted value 2.34
# Profile: marital_status_Married|age_range_46-55|family_size_5+|income_bracket_6.0 | Group size: 44 → Best coupon 468 with predicted value 2.09
# Profile: marital_status_Married|age_range_46-55|family_size_5+|income_bracket_8.0 | Group size: 69 → Best coupon 1070 with predicted value 2.14
# Profile: marital_status_Married|age_range_46-55|family_size_5+|income_bracket_9.0 | Group size: 30 → Best coupon 754 with predicted value 2.02
# Profile: marital_status_Married|age_range_56-70|family_size_2|income_bracket_1.0 | Group size: 68 → Best coupon 572 with predicted value 2.06
# Profile: marital_status_Married|age_range_56-70|family_size_2|income_bracket_2.0 | Group size: 41 → Best coupon 468 with predicted value 2.25
# Profile: marital_status_Married|age_range_56-70|family_size_2|income_bracket_3.0 | Group size: 22 → Best coupon 960 with predicted value 2.21
# Profile: marital_status_Married|age_range_56-70|family_size_2|income_bracket_4.0 | Group size: 90 → Best coupon 1075 with predicted value 2.16
# Profile: marital_status_Married|age_range_56-70|family_size_2|income_bracket_5.0 | Group size: 247 → Best coupon 1075 with predicted value 2.16
# Profile: marital_status_Married|age_range_56-70|family_size_2|income_bracket_6.0 | Group size: 110 → Best coupon 1075 with predicted value 2.22
# Profile: marital_status_Married|age_range_56-70|family_size_2|income_bracket_7.0 | Group size: 48 → Best coupon 1081 with predicted value 2.18
# Profile: marital_status_Married|age_range_56-70|family_size_2|income_bracket_8.0 | Group size: 34 → Best coupon 868 with predicted value 2.07
# Profile: marital_status_Married|age_range_56-70|family_size_2|income_bracket_9.0 | Group size: 118 → Best coupon 492 with predicted value 2.08
# Profile: marital_status_Married|age_range_56-70|family_size_3|income_bracket_4.0 | Group size: 7 → Best coupon 960 with predicted value 2.22
# Profile: marital_status_Married|age_range_56-70|family_size_4|income_bracket_4.0 | Group size: 13 → Best coupon 619 with predicted value 2.02
# Profile: marital_status_Married|age_range_56-70|family_size_4|income_bracket_6.0 | Group size: 58 → Best coupon 1059 with predicted value 1.99
# Profile: marital_status_Married|age_range_56-70|family_size_4|income_bracket_7.0 | Group size: 53 → Best coupon 772 with predicted value 1.96
# Profile: marital_status_Married|age_range_56-70|family_size_5+|income_bracket_4.0 | Group size: 1 → Best coupon 983 with predicted value 2.02
# Profile: marital_status_Married|age_range_56-70|family_size_5+|income_bracket_5.0 | Group size: 72 → Best coupon 468 with predicted value 2.05
# Profile: marital_status_Married|age_range_70+|family_size_2|income_bracket_1.0 | Group size: 5 → Best coupon 942 with predicted value 1.99
# Profile: marital_status_Married|age_range_70+|family_size_2|income_bracket_2.0 | Group size: 8 → Best coupon 64 with predicted value 2.00
# Profile: marital_status_Married|age_range_70+|family_size_2|income_bracket_3.0 | Group size: 16 → Best coupon 597 with predicted value 2.03
# Profile: marital_status_Married|age_range_70+|family_size_2|income_bracket_4.0 | Group size: 147 → Best coupon 819 with predicted value 2.06
# Profile: marital_status_Married|age_range_70+|family_size_2|income_bracket_5.0 | Group size: 229 → Best coupon 772 with predicted value 2.03
# Profile: marital_status_Married|age_range_70+|family_size_2|income_bracket_6.0 | Group size: 62 → Best coupon 64 with predicted value 2.02
# Profile: marital_status_Married|age_range_70+|family_size_2|income_bracket_7.0 | Group size: 1 → Best coupon 1081 with predicted value 2.06
# Profile: marital_status_Married|age_range_70+|family_size_2|income_bracket_8.0 | Group size: 29 → Best coupon 754 with predicted value 2.04
# Profile: marital_status_Married|age_range_70+|family_size_3|income_bracket_4.0 | Group size: 17 → Best coupon 754 with predicted value 2.00
# Profile: marital_status_Married|age_range_70+|family_size_3|income_bracket_7.0 | Group size: 9 → Best coupon 754 with predicted value 1.99
# Profile: marital_status_Single|age_range_18-25|family_size_1|income_bracket_12.0 | Group size: 10 → Best coupon 23 with predicted value 2.20
# Profile: marital_status_Single|age_range_18-25|family_size_1|income_bracket_4.0 | Group size: 34 → Best coupon 619 with predicted value 1.95
# Profile: marital_status_Single|age_range_18-25|family_size_1|income_bracket_5.0 | Group size: 25 → Best coupon 445 with predicted value 2.20
# Profile: marital_status_Single|age_range_18-25|family_size_2|income_bracket_1.0 | Group size: 23 → Best coupon 982 with predicted value 2.35
# Profile: marital_status_Single|age_range_18-25|family_size_2|income_bracket_3.0 | Group size: 3 → Best coupon 597 with predicted value 2.22
# Profile: marital_status_Single|age_range_18-25|family_size_2|income_bracket_5.0 | Group size: 22 → Best coupon 982 with predicted value 2.05
# Profile: marital_status_Single|age_range_18-25|family_size_3|income_bracket_5.0 | Group size: 3 → Best coupon 870 with predicted value 2.19
# Profile: marital_status_Single|age_range_18-25|family_size_4|income_bracket_1.0 | Group size: 47 → Best coupon 982 with predicted value 2.49
# Profile: marital_status_Single|age_range_26-35|family_size_1|income_bracket_1.0 | Group size: 22 → Best coupon 942 with predicted value 2.19
# Profile: marital_status_Single|age_range_26-35|family_size_1|income_bracket_10.0 | Group size: 39 → Best coupon 597 with predicted value 2.28
# Profile: marital_status_Single|age_range_26-35|family_size_1|income_bracket_2.0 | Group size: 4 → Best coupon 468 with predicted value 2.20
# Profile: marital_status_Single|age_range_26-35|family_size_1|income_bracket_3.0 | Group size: 3 → Best coupon 597 with predicted value 2.29
# Profile: marital_status_Single|age_range_26-35|family_size_1|income_bracket_4.0 | Group size: 129 → Best coupon 445 with predicted value 2.18
# Profile: marital_status_Single|age_range_26-35|family_size_1|income_bracket_5.0 | Group size: 132 → Best coupon 445 with predicted value 2.44
# Profile: marital_status_Single|age_range_26-35|family_size_1|income_bracket_7.0 | Group size: 9 → Best coupon 1081 with predicted value 2.24
# Profile: marital_status_Single|age_range_26-35|family_size_1|income_bracket_9.0 | Group size: 47 → Best coupon 942 with predicted value 2.26
# Profile: marital_status_Single|age_range_26-35|family_size_2|income_bracket_1.0 | Group size: 15 → Best coupon 942 with predicted value 2.17
# Profile: marital_status_Single|age_range_26-35|family_size_2|income_bracket_4.0 | Group size: 4 → Best coupon 1081 with predicted value 2.17
# Profile: marital_status_Single|age_range_26-35|family_size_2|income_bracket_8.0 | Group size: 34 → Best coupon 868 with predicted value 2.09
# Profile: marital_status_Single|age_range_26-35|family_size_3|income_bracket_1.0 | Group size: 28 → Best coupon 705 with predicted value 1.98
# Profile: marital_status_Single|age_range_26-35|family_size_3|income_bracket_3.0 | Group size: 89 → Best coupon 597 with predicted value 2.15
# Profile: marital_status_Single|age_range_26-35|family_size_3|income_bracket_4.0 | Group size: 5 → Best coupon 1081 with predicted value 2.03
# Profile: marital_status_Single|age_range_26-35|family_size_5+|income_bracket_3.0 | Group size: 27 → Best coupon 318 with predicted value 1.89
# Profile: marital_status_Single|age_range_36-45|family_size_1|income_bracket_1.0 | Group size: 29 → Best coupon 91 with predicted value 2.11
# Profile: marital_status_Single|age_range_36-45|family_size_1|income_bracket_2.0 | Group size: 78 → Best coupon 468 with predicted value 2.20
# Profile: marital_status_Single|age_range_36-45|family_size_1|income_bracket_3.0 | Group size: 128 → Best coupon 597 with predicted value 2.56
# Profile: marital_status_Single|age_range_36-45|family_size_1|income_bracket_4.0 | Group size: 31 → Best coupon 445 with predicted value 2.09
# Profile: marital_status_Single|age_range_36-45|family_size_1|income_bracket_5.0 | Group size: 11 → Best coupon 445 with predicted value 2.35
# Profile: marital_status_Single|age_range_36-45|family_size_1|income_bracket_6.0 | Group size: 61 → Best coupon 597 with predicted value 2.37
# Profile: marital_status_Single|age_range_36-45|family_size_1|income_bracket_8.0 | Group size: 10 → Best coupon 597 with predicted value 2.44
# Profile: marital_status_Single|age_range_36-45|family_size_1|income_bracket_9.0 | Group size: 24 → Best coupon 597 with predicted value 2.29
# Profile: marital_status_Single|age_range_36-45|family_size_2|income_bracket_4.0 | Group size: 241 → Best coupon 1065 with predicted value 2.10
# Profile: marital_status_Single|age_range_36-45|family_size_2|income_bracket_6.0 | Group size: 9 → Best coupon 27 with predicted value 2.36
# Profile: marital_status_Single|age_range_36-45|family_size_3|income_bracket_4.0 | Group size: 6 → Best coupon 619 with predicted value 1.92
# Profile: marital_status_Single|age_range_36-45|family_size_3|income_bracket_5.0 | Group size: 12 → Best coupon 445 with predicted value 2.17
# Profile: marital_status_Single|age_range_36-45|family_size_3|income_bracket_6.0 | Group size: 2 → Best coupon 597 with predicted value 2.23
# Profile: marital_status_Single|age_range_36-45|family_size_4|income_bracket_4.0 | Group size: 70 → Best coupon 559 with predicted value 1.96
# Profile: marital_status_Single|age_range_46-55|family_size_1|income_bracket_4.0 | Group size: 51 → Best coupon 59 with predicted value 2.03
# Profile: marital_status_Single|age_range_46-55|family_size_1|income_bracket_5.0 | Group size: 181 → Best coupon 445 with predicted value 2.26
# Profile: marital_status_Single|age_range_46-55|family_size_1|income_bracket_7.0 | Group size: 77 → Best coupon 1081 with predicted value 2.06
# Profile: marital_status_Single|age_range_46-55|family_size_1|income_bracket_9.0 | Group size: 1 → Best coupon 942 with predicted value 2.27
# Profile: marital_status_Single|age_range_46-55|family_size_2|income_bracket_3.0 | Group size: 97 → Best coupon 865 with predicted value 2.46
# Profile: marital_status_Single|age_range_46-55|family_size_2|income_bracket_4.0 | Group size: 69 → Best coupon 865 with predicted value 2.12
# Profile: marital_status_Single|age_range_46-55|family_size_2|income_bracket_5.0 | Group size: 13 → Best coupon 865 with predicted value 2.39
# Profile: marital_status_Single|age_range_46-55|family_size_2|income_bracket_7.0 | Group size: 7 → Best coupon 786 with predicted value 2.16
# Profile: marital_status_Single|age_range_46-55|family_size_3|income_bracket_5.0 | Group size: 1 → Best coupon 865 with predicted value 2.34
# Profile: marital_status_Single|age_range_46-55|family_size_4|income_bracket_3.0 | Group size: 13 → Best coupon 597 with predicted value 2.10
# Profile: marital_status_Single|age_range_56-70|family_size_1|income_bracket_10.0 | Group size: 4 → Best coupon 597 with predicted value 2.29
# Profile: marital_status_Single|age_range_56-70|family_size_1|income_bracket_3.0 | Group size: 41 → Best coupon 597 with predicted value 2.30
# Profile: marital_status_Single|age_range_56-70|family_size_1|income_bracket_4.0 | Group size: 40 → Best coupon 22 with predicted value 2.10
# Profile: marital_status_Single|age_range_56-70|family_size_1|income_bracket_6.0 | Group size: 11 → Best coupon 597 with predicted value 2.11
# Profile: marital_status_Single|age_range_56-70|family_size_2|income_bracket_1.0 | Group size: 63 → Best coupon 144 with predicted value 2.07
# Profile: marital_status_Single|age_range_56-70|family_size_2|income_bracket_4.0 | Group size: 26 → Best coupon 619 with predicted value 2.01
# Profile: marital_status_Single|age_range_70+|family_size_1|income_bracket_2.0 | Group size: 12 → Best coupon 468 with predicted value 1.94
# Profile: marital_status_Single|age_range_70+|family_size_1|income_bracket_3.0 | Group size: 7 → Best coupon 597 with predicted value 2.33
# Profile: marital_status_Single|age_range_70+|family_size_1|income_bracket_4.0 | Group size: 125 → Best coupon 942 with predicted value 2.27
# Profile: marital_status_Single|age_range_70+|family_size_1|income_bracket_7.0 | Group size: 26 → Best coupon 942 with predicted value 2.07
# Profile: marital_status_Single|age_range_70+|family_size_2|income_bracket_1.0 | Group size: 10 → Best coupon 942 with predicted value 2.43
# Profile: marital_status_Single|age_range_70+|family_size_2|income_bracket_4.0 | Group size: 23 → Best coupon 942 with predicted value 2.26
# Profile: marital_status_Unknown|age_range_18-25|family_size_1|income_bracket_1.0 | Group size: 82 → Best coupon 982 with predicted value 2.39
# Profile: marital_status_Unknown|age_range_18-25|family_size_1|income_bracket_3.0 | Group size: 33 → Best coupon 597 with predicted value 2.40
# Profile: marital_status_Unknown|age_range_18-25|family_size_1|income_bracket_4.0 | Group size: 10 → Best coupon 981 with predicted value 2.15
# Profile: marital_status_Unknown|age_range_18-25|family_size_1|income_bracket_5.0 | Group size: 68 → Best coupon 780 with predicted value 2.17
# Profile: marital_status_Unknown|age_range_18-25|family_size_2|income_bracket_1.0 | Group size: 3 → Best coupon 982 with predicted value 2.31
# Profile: marital_status_Unknown|age_range_18-25|family_size_2|income_bracket_2.0 | Group size: 11 → Best coupon 529 with predicted value 2.38
# Profile: marital_status_Unknown|age_range_18-25|family_size_2|income_bracket_4.0 | Group size: 25 → Best coupon 1020 with predicted value 2.23
# Profile: marital_status_Unknown|age_range_18-25|family_size_2|income_bracket_5.0 | Group size: 5 → Best coupon 512 with predicted value 2.10
# Profile: marital_status_Unknown|age_range_18-25|family_size_2|income_bracket_6.0 | Group size: 18 → Best coupon 529 with predicted value 2.24
# Profile: marital_status_Unknown|age_range_18-25|family_size_3|income_bracket_5.0 | Group size: 19 → Best coupon 870 with predicted value 2.06
# Profile: marital_status_Unknown|age_range_18-25|family_size_4|income_bracket_4.0 | Group size: 12 → Best coupon 529 with predicted value 2.14
# Profile: marital_status_Unknown|age_range_26-35|family_size_1|income_bracket_2.0 | Group size: 60 → Best coupon 439 with predicted value 2.22
# Profile: marital_status_Unknown|age_range_26-35|family_size_1|income_bracket_3.0 | Group size: 69 → Best coupon 597 with predicted value 2.22
# Profile: marital_status_Unknown|age_range_26-35|family_size_1|income_bracket_4.0 | Group size: 84 → Best coupon 1081 with predicted value 2.29
# Profile: marital_status_Unknown|age_range_26-35|family_size_1|income_bracket_5.0 | Group size: 10 → Best coupon 526 with predicted value 2.40
# Profile: marital_status_Unknown|age_range_26-35|family_size_1|income_bracket_6.0 | Group size: 25 → Best coupon 569 with predicted value 2.15
# Profile: marital_status_Unknown|age_range_26-35|family_size_1|income_bracket_7.0 | Group size: 66 → Best coupon 1081 with predicted value 2.44
# Profile: marital_status_Unknown|age_range_26-35|family_size_2|income_bracket_1.0 | Group size: 36 → Best coupon 661 with predicted value 2.09
# Profile: marital_status_Unknown|age_range_26-35|family_size_2|income_bracket_2.0 | Group size: 28 → Best coupon 439 with predicted value 2.21
# Profile: marital_status_Unknown|age_range_26-35|family_size_2|income_bracket_3.0 | Group size: 7 → Best coupon 770 with predicted value 2.24
# Profile: marital_status_Unknown|age_range_26-35|family_size_2|income_bracket_4.0 | Group size: 69 → Best coupon 601 with predicted value 2.44
# Profile: marital_status_Unknown|age_range_26-35|family_size_2|income_bracket_5.0 | Group size: 176 → Best coupon 526 with predicted value 2.54
# Profile: marital_status_Unknown|age_range_26-35|family_size_2|income_bracket_6.0 | Group size: 22 → Best coupon 601 with predicted value 2.39
# Profile: marital_status_Unknown|age_range_26-35|family_size_2|income_bracket_9.0 | Group size: 41 → Best coupon 1081 with predicted value 2.19
# Profile: marital_status_Unknown|age_range_26-35|family_size_3|income_bracket_1.0 | Group size: 7 → Best coupon 625 with predicted value 2.06
# Profile: marital_status_Unknown|age_range_26-35|family_size_3|income_bracket_3.0 | Group size: 85 → Best coupon 770 with predicted value 2.23
# Profile: marital_status_Unknown|age_range_26-35|family_size_3|income_bracket_4.0 | Group size: 66 → Best coupon 770 with predicted value 2.24
# Profile: marital_status_Unknown|age_range_26-35|family_size_3|income_bracket_6.0 | Group size: 6 → Best coupon 601 with predicted value 2.16
# Profile: marital_status_Unknown|age_range_26-35|family_size_3|income_bracket_9.0 | Group size: 94 → Best coupon 622 with predicted value 2.27
# Profile: marital_status_Unknown|age_range_26-35|family_size_4|income_bracket_2.0 | Group size: 29 → Best coupon 705 with predicted value 2.04
# Profile: marital_status_Unknown|age_range_26-35|family_size_4|income_bracket_6.0 | Group size: 53 → Best coupon 601 with predicted value 2.33
# Profile: marital_status_Unknown|age_range_26-35|family_size_4|income_bracket_8.0 | Group size: 109 → Best coupon 705 with predicted value 2.06
# Profile: marital_status_Unknown|age_range_26-35|family_size_5+|income_bracket_3.0 | Group size: 22 → Best coupon 1084 with predicted value 2.09
# Profile: marital_status_Unknown|age_range_26-35|family_size_5+|income_bracket_5.0 | Group size: 29 → Best coupon 678 with predicted value 2.29
# Profile: marital_status_Unknown|age_range_36-45|family_size_1|income_bracket_1.0 | Group size: 37 → Best coupon 91 with predicted value 2.09
# Profile: marital_status_Unknown|age_range_36-45|family_size_1|income_bracket_2.0 | Group size: 249 → Best coupon 468 with predicted value 2.19
# Profile: marital_status_Unknown|age_range_36-45|family_size_1|income_bracket_3.0 | Group size: 12 → Best coupon 597 with predicted value 2.49
# Profile: marital_status_Unknown|age_range_36-45|family_size_1|income_bracket_4.0 | Group size: 60 → Best coupon 510 with predicted value 2.42
# Profile: marital_status_Unknown|age_range_36-45|family_size_1|income_bracket_5.0 | Group size: 409 → Best coupon 669 with predicted value 2.19
# Profile: marital_status_Unknown|age_range_36-45|family_size_1|income_bracket_6.0 | Group size: 27 → Best coupon 248 with predicted value 2.31
# Profile: marital_status_Unknown|age_range_36-45|family_size_1|income_bracket_9.0 | Group size: 122 → Best coupon 597 with predicted value 2.22
# Profile: marital_status_Unknown|age_range_36-45|family_size_2|income_bracket_1.0 | Group size: 140 → Best coupon 1017 with predicted value 2.10
# Profile: marital_status_Unknown|age_range_36-45|family_size_2|income_bracket_2.0 | Group size: 4 → Best coupon 136 with predicted value 2.07
# Profile: marital_status_Unknown|age_range_36-45|family_size_2|income_bracket_3.0 | Group size: 32 → Best coupon 884 with predicted value 2.35
# Profile: marital_status_Unknown|age_range_36-45|family_size_2|income_bracket_4.0 | Group size: 12 → Best coupon 559 with predicted value 2.33
# Profile: marital_status_Unknown|age_range_36-45|family_size_2|income_bracket_5.0 | Group size: 56 → Best coupon 532 with predicted value 2.39
# Profile: marital_status_Unknown|age_range_36-45|family_size_2|income_bracket_6.0 | Group size: 83 → Best coupon 532 with predicted value 2.40
# Profile: marital_status_Unknown|age_range_36-45|family_size_2|income_bracket_8.0 | Group size: 74 → Best coupon 810 with predicted value 2.18
# Profile: marital_status_Unknown|age_range_36-45|family_size_2|income_bracket_9.0 | Group size: 65 → Best coupon 492 with predicted value 2.23
# Profile: marital_status_Unknown|age_range_36-45|family_size_3|income_bracket_2.0 | Group size: 31 → Best coupon 674 with predicted value 2.13
# Profile: marital_status_Unknown|age_range_36-45|family_size_3|income_bracket_4.0 | Group size: 18 → Best coupon 510 with predicted value 2.37
# Profile: marital_status_Unknown|age_range_36-45|family_size_3|income_bracket_5.0 | Group size: 17 → Best coupon 622 with predicted value 2.30
# Profile: marital_status_Unknown|age_range_36-45|family_size_3|income_bracket_6.0 | Group size: 27 → Best coupon 902 with predicted value 2.22
# Profile: marital_status_Unknown|age_range_36-45|family_size_4|income_bracket_2.0 | Group size: 40 → Best coupon 510 with predicted value 2.01
# Profile: marital_status_Unknown|age_range_36-45|family_size_4|income_bracket_5.0 | Group size: 8 → Best coupon 532 with predicted value 2.15
# Profile: marital_status_Unknown|age_range_36-45|family_size_5+|income_bracket_4.0 | Group size: 14 → Best coupon 510 with predicted value 2.31
# Profile: marital_status_Unknown|age_range_46-55|family_size_1|income_bracket_1.0 | Group size: 176 → Best coupon 1017 with predicted value 2.08
# Profile: marital_status_Unknown|age_range_46-55|family_size_1|income_bracket_10.0 | Group size: 28 → Best coupon 597 with predicted value 2.17
# Profile: marital_status_Unknown|age_range_46-55|family_size_1|income_bracket_2.0 | Group size: 78 → Best coupon 468 with predicted value 2.22
# Profile: marital_status_Unknown|age_range_46-55|family_size_1|income_bracket_3.0 | Group size: 71 → Best coupon 318 with predicted value 2.28
# Profile: marital_status_Unknown|age_range_46-55|family_size_1|income_bracket_4.0 | Group size: 195 → Best coupon 510 with predicted value 2.31
# Profile: marital_status_Unknown|age_range_46-55|family_size_1|income_bracket_5.0 | Group size: 1038 → Best coupon 986 with predicted value 2.27
# Profile: marital_status_Unknown|age_range_46-55|family_size_1|income_bracket_6.0 | Group size: 157 → Best coupon 812 with predicted value 2.26
# Profile: marital_status_Unknown|age_range_46-55|family_size_1|income_bracket_7.0 | Group size: 48 → Best coupon 1081 with predicted value 2.25
# Profile: marital_status_Unknown|age_range_46-55|family_size_1|income_bracket_8.0 | Group size: 13 → Best coupon 989 with predicted value 2.14
# Profile: marital_status_Unknown|age_range_46-55|family_size_1|income_bracket_9.0 | Group size: 23 → Best coupon 124 with predicted value 2.16
# Profile: marital_status_Unknown|age_range_46-55|family_size_2|income_bracket_1.0 | Group size: 77 → Best coupon 906 with predicted value 2.19
# Profile: marital_status_Unknown|age_range_46-55|family_size_2|income_bracket_12.0 | Group size: 17 → Best coupon 705 with predicted value 2.16
# Profile: marital_status_Unknown|age_range_46-55|family_size_2|income_bracket_2.0 | Group size: 57 → Best coupon 529 with predicted value 2.29
# Profile: marital_status_Unknown|age_range_46-55|family_size_2|income_bracket_3.0 | Group size: 213 → Best coupon 884 with predicted value 2.32
# Profile: marital_status_Unknown|age_range_46-55|family_size_2|income_bracket_4.0 | Group size: 106 → Best coupon 846 with predicted value 2.35
# Profile: marital_status_Unknown|age_range_46-55|family_size_2|income_bracket_5.0 | Group size: 194 → Best coupon 884 with predicted value 2.31
# Profile: marital_status_Unknown|age_range_46-55|family_size_2|income_bracket_6.0 | Group size: 63 → Best coupon 989 with predicted value 2.37
# Profile: marital_status_Unknown|age_range_46-55|family_size_2|income_bracket_9.0 | Group size: 9 → Best coupon 824 with predicted value 2.14
# Profile: marital_status_Unknown|age_range_46-55|family_size_3|income_bracket_10.0 | Group size: 67 → Best coupon 597 with predicted value 2.04
# Profile: marital_status_Unknown|age_range_46-55|family_size_3|income_bracket_2.0 | Group size: 2 → Best coupon 529 with predicted value 2.12
# Profile: marital_status_Unknown|age_range_46-55|family_size_3|income_bracket_3.0 | Group size: 34 → Best coupon 865 with predicted value 2.20
# Profile: marital_status_Unknown|age_range_46-55|family_size_3|income_bracket_4.0 | Group size: 70 → Best coupon 510 with predicted value 2.26
# Profile: marital_status_Unknown|age_range_46-55|family_size_3|income_bracket_6.0 | Group size: 1 → Best coupon 989 with predicted value 2.36
# Profile: marital_status_Unknown|age_range_46-55|family_size_3|income_bracket_9.0 | Group size: 4 → Best coupon 622 with predicted value 2.25
# Profile: marital_status_Unknown|age_range_46-55|family_size_4|income_bracket_2.0 | Group size: 12 → Best coupon 529 with predicted value 2.29
# Profile: marital_status_Unknown|age_range_46-55|family_size_4|income_bracket_4.0 | Group size: 46 → Best coupon 510 with predicted value 2.20
# Profile: marital_status_Unknown|age_range_46-55|family_size_4|income_bracket_5.0 | Group size: 118 → Best coupon 622 with predicted value 2.15
# Profile: marital_status_Unknown|age_range_46-55|family_size_5+|income_bracket_8.0 | Group size: 37 → Best coupon 136 with predicted value 2.08
# Profile: marital_status_Unknown|age_range_56-70|family_size_1|income_bracket_1.0 | Group size: 12 → Best coupon 317 with predicted value 2.04
# Profile: marital_status_Unknown|age_range_56-70|family_size_1|income_bracket_2.0 | Group size: 7 → Best coupon 468 with predicted value 2.28
# Profile: marital_status_Unknown|age_range_56-70|family_size_1|income_bracket_3.0 | Group size: 53 → Best coupon 597 with predicted value 2.23
# Profile: marital_status_Unknown|age_range_56-70|family_size_1|income_bracket_4.0 | Group size: 16 → Best coupon 1081 with predicted value 2.12
# Profile: marital_status_Unknown|age_range_56-70|family_size_1|income_bracket_5.0 | Group size: 34 → Best coupon 526 with predicted value 2.23
# Profile: marital_status_Unknown|age_range_56-70|family_size_1|income_bracket_6.0 | Group size: 185 → Best coupon 248 with predicted value 2.34
# Profile: marital_status_Unknown|age_range_56-70|family_size_1|income_bracket_9.0 | Group size: 12 → Best coupon 124 with predicted value 2.15
# Profile: marital_status_Unknown|age_range_56-70|family_size_2|income_bracket_4.0 | Group size: 21 → Best coupon 601 with predicted value 2.34
# Profile: marital_status_Unknown|age_range_56-70|family_size_3|income_bracket_2.0 | Group size: 36 → Best coupon 468 with predicted value 2.10
# Profile: marital_status_Unknown|age_range_56-70|family_size_3|income_bracket_3.0 | Group size: 8 → Best coupon 597 with predicted value 2.09
# Profile: marital_status_Unknown|age_range_70+|family_size_1|income_bracket_1.0 | Group size: 26 → Best coupon 942 with predicted value 2.16
# Profile: marital_status_Unknown|age_range_70+|family_size_1|income_bracket_2.0 | Group size: 151 → Best coupon 64 with predicted value 1.97
# Profile: marital_status_Unknown|age_range_70+|family_size_1|income_bracket_4.0 | Group size: 10 → Best coupon 67 with predicted value 2.14
# Profile: marital_status_Unknown|age_range_70+|family_size_1|income_bracket_5.0 | Group size: 8 → Best coupon 124 with predicted value 2.09
# Profile: marital_status_Unknown|age_range_70+|family_size_1|income_bracket_7.0 | Group size: 9 → Best coupon 1081 with predicted value 2.13
# Profile: marital_status_Unknown|age_range_70+|family_size_2|income_bracket_3.0 | Group size: 26 → Best coupon 906 with predicted value 2.04
# Profile: marital_status_Unknown|age_range_70+|family_size_2|income_bracket_4.0 | Group size: 9 → Best coupon 601 with predicted value 2.22
# Profile: marital_status_Unknown|age_range_70+|family_size_2|income_bracket_5.0 | Group size: 3 → Best coupon 705 with predicted value 2.09
# Profile: marital_status_Unknown|age_range_70+|family_size_2|income_bracket_9.0 | Group size: 9 → Best coupon 942 with predicted value 2.22
# Profile: marital_status_Unknown|age_range_70+|family_size_3|income_bracket_1.0 | Group size: 47 → Best coupon 705 with predicted value 1.97
# Profile: marital_status_Unknown|age_range_70+|family_size_3|income_bracket_8.0 | Group size: 2 → Best coupon 705 with predicted value 2.01
# Profile: marital_status_Unknown|age_range_Unknown|family_size_Unknown|income_bracket_Unknown | Group size: 7614 → Best coupon 754 with predicted value 1.99
